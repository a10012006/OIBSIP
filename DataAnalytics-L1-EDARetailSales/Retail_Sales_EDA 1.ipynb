# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\hp\Downloads\retail_sales_dataset.csv")

df.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
import os

print(os.listdir(r"C:\Users\hp\Downloads"))
# Out:
# ['(6) WhatsApp.html', '(6) WhatsApp_files', '.ipynb_checkpoints', '01_CHEM_Nov-Dec -2024_(2024_Pat).pdf', '02_CHEM_May-Jun -2025_(2024_Pat).pdf', '06. BEE_INSEM March_2024.pdf', '06. BEE_May_Jun_2024.pdf', '07. BEE_INSEM Sep - 2024.pdf', '07. CHEM Nov_Dec_2024.pdf', '08. CHEM May_Jun_2025.pdf', '1000004457.jpg', '1000004463.jpg', '1000004466.jpg', '1000004473.jpg', '1000004475.jpg', '101_MA_QBDiv.A_Dr.-Poonam-M.-Khadke.pdf', '10th 20·16·30.pdf', '12th (1).pdf', '12th (2).pdf', '12th.pdf', '1712813663007.jpg', '18CS0510-Operating Systems.pdf', '197assignment-152630-143832-691c2f13b0796 (1).docx', '197assignment-152630-143832-691c2f13b0796 (2).docx', '197assignment-152630-143832-691c2f13b0796.docx', '1st program (1).docx', '1st program.docx', '5_6325344713599619636 (1).pdf', '5_6325344713599619636.pdf', '8c095aec-101b-45d0-b036-719f55fc89ee.mp3', 'AanamResume (1).docx', 'academic-process-mining-fundamentals.png', 'ACE Scanner_2025_07_04(4).pdf', 'ACE Scanner_2025_07_04(5) (1).pdf', 'AC
# ...

# %%
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])
print("Dataset shape:", df.shape)
# Out:
# Number of rows: 1000
# Number of columns: 9
# Dataset shape: (1000, 9)

# %%
print("Column Names:")
print(df.columns.tolist())
# Out:
# Column Names:
# ['Transaction ID', 'Date', 'Customer ID', 'Gender', 'Age', 'Product Category', 'Quantity', 'Price per Unit', 'Total Amount']

# %%
df.dtypes
# Out:
# Transaction ID      int64
# Date                  str
# Customer ID           str
# Gender                str
# Age                 int64
# Product Category      str
# Quantity            int64
# Price per Unit      int64
# Total Amount        int64
# dtype: object

# %%
print("Missing values in each column:")
print(df.isnull().sum())
# Out:
# Missing values in each column:
# Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   str
#  2   Customer ID       1000 non-null   str
#  3   Gender            1000 non-null   str
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   str
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: int64(5), str(4)
# memory usage: 70.4 KB

# %% [markdown]
# ## Initial Dataset Inspection
#
# The dataset was successfully loaded and inspected. The dataset contains retail transaction records with information about transactions, customers, products, quantities, prices, and total sales.
#
# The data types, dataset dimensions, and missing values were checked before performing further analysis.

# %%
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])
print("Dataset shape:", df.shape)
# Out:
# Number of rows: 1000
# Number of columns: 9
# Dataset shape: (1000, 9)

# %%
print("Column Names:")
print(df.columns.tolist())
# Out:
# Column Names:
# ['Transaction ID', 'Date', 'Customer ID', 'Gender', 'Age', 'Product Category', 'Quantity', 'Price per Unit', 'Total Amount']

# %%
df.dtypes
# Out:
# Transaction ID      int64
# Date                  str
# Customer ID           str
# Gender                str
# Age                 int64
# Product Category      str
# Quantity            int64
# Price per Unit      int64
# Total Amount        int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64

# %%
# Select numerical columns
numerical_cols = df.select_dtypes(include='number').columns

print("Numerical Columns:")
print(numerical_cols)

print("\n--- MEAN ---")
print(df[numerical_cols].mean())

print("\n--- MEDIAN ---")
print(df[numerical_cols].median())

print("\n--- MODE ---")
print(df[numerical_cols].mode().iloc[0])

print("\n--- STANDARD DEVIATION ---")
print(df[numerical_cols].std())
# Out:
# Numerical Columns:
# Index(['Transaction ID', 'Age', 'Quantity', 'Price per Unit', 'Total Amount'], dtype='str')
#
# --- MEAN ---
# Transaction ID    500.500
# Age                41.392
# Quantity            2.514
# Price per Unit    179.890
# Total Amount      456.000
# dtype: float64
#
# --- MEDIAN ---
# Transaction ID    500.5
# Age                42.0
# Quantity            3.0
# Price per Unit     50.0
# Total Amount      135.0
# dtype: float64
#
# --- MODE ---
# Transaction ID     1.0
# Age               43.0
# Quantity           4.0
# Price per Unit    50.0
# Total Amount      50.0
# Name: 0, dtype: float64
#
# --- STANDARD DEVIATION ---
# Transaction ID    288.819436
# Age                13.681430
# Quantity            1.132734
# Price per Unit    189.681356
# Total Amount      559.997632
# dtype: float64

# %% [markdown]
# ### Observation
#
# The descriptive statistics show that the average customer age is 41.39 years, with a median of 42 years. Customers purchase an average of 2.51 units per transaction.
#
# The average price per unit is ₹179.89 and the average transaction value is ₹456. The relatively high standard deviation of Total Amount (₹559.99) indicates considerable variation in transaction values, suggesting that some purchases are much larger than others.

# %%
df['Date'] = pd.to_datetime(df['Date'])

print(df['Date'].dtype)
# Out:
# datetime64[us]

# %%
monthly_sales = df.groupby(
    df['Date'].dt.to_period('M')
)['Total Amount'].sum()

print(monthly_sales)
# Out:
# Date
# 2023-01    35450
# 2023-02    44060
# 2023-03    28990
# 2023-04    33870
# 2023-05    53150
# 2023-06    36715
# 2023-07    35465
# 2023-08    36960
# 2023-09    23620
# 2023-10    46580
# 2023-11    34920
# 2023-12    44690
# 2024-01     1530
# Freq: M, Name: Total Amount, dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
df = pd.read_csv(r"C:\Users\hp\Downloads\retail_sales_dataset.csv")

df.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
df['Date'] = pd.to_datetime(df['Date'])

print(df['Date'].dtype)
# Out:
# datetime64[us]

# %%
monthly_sales = df.groupby(
    df['Date'].dt.to_period('M')
)['Total Amount'].sum()

monthly_sales
# Out:
# Date
# 2023-01    35450
# 2023-02    44060
# 2023-03    28990
# 2023-04    33870
# 2023-05    53150
# 2023-06    36715
# 2023-07    35465
# 2023-08    36960
# 2023-09    23620
# 2023-10    46580
# 2023-11    34920
# 2023-12    44690
# 2024-01     1530
# Freq: M, Name: Total Amount, dtype: int64

# %%
plt.figure(figsize=(12, 5))

plt.plot(
    monthly_sales.index.astype(str),
    monthly_sales.values,
    marker='o'
)

plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Total Sales (₹)")
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Observation
#
# The monthly sales trend shows variations in sales across different months of 2023. The fluctuations indicate that customer demand is not constant throughout the year. The months with higher sales can be considered peak periods, while months with lower sales may require additional promotional activities.
#
# This analysis can help the business plan inventory, marketing campaigns, and sales strategies according to monthly demand.

# %%
quarterly_sales = df.groupby(
    df['Date'].dt.to_period('Q')
)['Total Amount'].sum()

quarterly_sales
# Out:
# Date
# 2023Q1    108500
# 2023Q2    123735
# 2023Q3     96045
# 2023Q4    126190
# 2024Q1      1530
# Freq: Q-DEC, Name: Total Amount, dtype: int64

# %%
plt.figure(figsize=(10, 5))

plt.plot(
    quarterly_sales.index.astype(str),
    quarterly_sales.values,
    marker='o'
)

plt.title("Quarterly Sales Trend")
plt.xlabel("Quarter")
plt.ylabel("Total Sales (₹)")
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
age_bins = [0, 18, 25, 35, 45, 55, 65, 100]

age_labels = [
    'Under 18',
    '18-25',
    '26-35',
    '36-45',
    '46-55',
    '56-65',
    '65+'
]

df['Age Group'] = pd.cut(
    df['Age'],
    bins=age_bins,
    labels=age_labels
)

df['Age Group'].value_counts().sort_index()
# Out:
# Age Group
# Under 18     21
# 18-25       148
# 26-35       205
# 36-45       202
# 46-55       229
# 56-65       195
# 65+           0
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 5))

sns.countplot(
    data=df,
    x='Age Group',
    order=age_labels
)

plt.title("Customer Age Group Distribution")
plt.xlabel("Age Group")
plt.ylabel("Number of Customers")

plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Observation
#
# The age group distribution shows that customers aged 46–55 form the largest customer segment in the dataset. The 26–35 and 36–45 age groups also represent a significant share of customers.
#
# The 18–25 group has fewer customers, while customers under 18 and above 65 represent very small portions of the dataset.
#
# This suggests that the business should focus its marketing and product strategies primarily on middle-aged customer segments, particularly the 46–55 age group.

# %%
gender_counts = df['Gender'].value_counts()

print(gender_counts)
# Out:
# Gender
# Female    510
# Male      490
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7, 5))

sns.barplot(
    x=gender_counts.index,
    y=gender_counts.values
)

plt.title("Customer Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Number of Customers")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Observation
#
# The gender distribution is relatively balanced, with female customers slightly outnumbering male customers. The difference between the two groups is small, indicating that the business has a broad customer base rather than being strongly concentrated in one gender.
#
# Therefore, marketing strategies should target both male and female customers instead of focusing exclusively on one group.

# %%
print(df['Product Category'].unique())
# Out:
# <StringArray>
# ['Beauty', 'Clothing', 'Electronics']
# Length: 3, dtype: str

# %%
top_categories = (
    df.groupby('Product Category')['Quantity']
    .sum()
    .sort_values(ascending=False)
)

print(top_categories)
# Out:
# Product Category
# Clothing       894
# Electronics    849
# Beauty         771
# Name: Quantity, dtype: int64

# %%
plt.figure(figsize=(8, 5))

sns.barplot(
    x=top_categories.index,
    y=top_categories.values
)

plt.title("Best-Selling Product Categories")
plt.xlabel("Product Category")
plt.ylabel("Total Quantity Sold")

plt.tight_layout()
plt.show()

# %% [markdown]
# ###
# Observation
#
# The analysis shows that Clothing has the highest total quantity sold, followed by Electronics and Beauty. Clothing therefore represents the strongest category in terms of unit demand.
#
# The business should maintain sufficient inventory for Clothing and Electronics to avoid stock shortages. Beauty has comparatively lower unit sales and may benefit from targeted promotions to increase demand.

# %%
category_revenue = (
    df.groupby('Product Category')['Total Amount']
    .sum()
    .sort_values(ascending=False)
)

print(category_revenue)
# Out:
# Product Category
# Electronics    156905
# Clothing       155580
# Beauty         143515
# Name: Total Amount, dtype: int64

# %%
plt.figure(figsize=(8, 5))

sns.barplot(
    x=category_revenue.index,
    y=category_revenue.values
)

plt.title("Revenue by Product Category")
plt.xlabel("Product Category")
plt.ylabel("Revenue (₹)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Observation
#
# Electronics generates the highest revenue at approximately ₹156,000, followed closely by Clothing at approximately ₹155,000. Beauty generates comparatively lower revenue at approximately ₹143,000.
#
# An interesting insight is that Clothing has the highest quantity sold, while Electronics generates the highest revenue. This indicates that sales volume and revenue performance do not always follow the same pattern.
#
# The business should maintain strong inventory levels for Electronics and Clothing while using targeted promotions to improve Beauty category revenue.

# %%
correlation = df.select_dtypes(include='number').corr()

correlation
# Out:
#                 Transaction ID       Age  Quantity  Price per Unit  \
# Transaction ID        1.000000  0.065191 -0.026623       -0.060837
# Age                   0.065191  1.000000 -0.023737       -0.038423
# Quantity             -0.026623 -0.023737  1.000000        0.017501
# Price per Unit       -0.060837 -0.038423  0.017501        1.000000
# Total Amount         -0.075034 -0.060568  0.373707        0.851925
#
#                 Total Amount
# Transaction ID     -0.075034
# Age                -0.060568
# Quantity            0.373707
# Price per Unit      0.851925
# Total Amount        1.000000

# %%
plt.figure(figsize=(10, 7))

sns.heatmap(
    correlation,
    annot=True,
    cmap='coolwarm',
    fmt='.2f'
)

plt.title("Correlation Matrix of Numerical Variables")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Observation
#
# The correlation heatmap shows a strong positive correlation of 0.85 between Price per Unit and Total Amount. This indicates that transactions involving higher-priced products generally generate higher total sales.
#
# Quantity and Total Amount have a moderate positive correlation of 0.37, suggesting that purchasing more units is also associated with higher transaction values.
#
# Age has very weak correlations with Total Amount (-0.06) and Quantity (-0.02), indicating that customer age has little linear relationship with transaction value or quantity purchased.

# %%
age_sales = (
    df.groupby('Age Group', observed=False)['Total Amount']
    .mean()
    .reindex(age_labels)
)

print(age_sales)
# Out:
# Age Group
# Under 18    534.047619
# 18-25       495.506757
# 26-35       480.390244
# 36-45       454.801980
# 46-55       439.694323
# 56-65       412.358974
# 65+                NaN
# Name: Total Amount, dtype: float64

# %%
plt.figure(figsize=(10, 5))

sns.barplot(
    x=age_sales.index,
    y=age_sales.values
)

plt.title("Average Transaction Value by Age Group")
plt.xlabel("Age Group")
plt.ylabel("Average Transaction Value (₹)")

plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %%
# Additional Visualization: Quantity vs Total Amount

plt.figure(figsize=(8, 5))

sns.scatterplot(
    data=df,
    x='Quantity',
    y='Total Amount'
)

plt.title('Quantity vs Total Amount')
plt.xlabel('Quantity Purchased')
plt.ylabel('Total Amount (₹)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Observation – Quantity vs Total Amount
#
# The scatter plot shows the relationship between the quantity purchased and the total transaction amount.
#
# There is a positive relationship between quantity and total amount, meaning that transactions with higher quantities generally tend to generate higher sales value. However, the relationship is not perfectly linear because the total amount also depends on the price per unit.
#
# This indicates that increasing the number of items purchased can increase transaction revenue, while higher-priced products can also significantly influence the final transaction value.

# %% [markdown]
# # Conclusion and Business Recommendations
#
# ## Conclusion
#
# The exploratory data analysis of the retail sales dataset revealed several useful patterns in customer behaviour, product performance, and transaction value.
#
# 1. **Customer demographics:** The analysis shows that customers are distributed across different age groups, with the 46–55 age group representing one of the larger customer segments. Male and female customer counts are relatively close, indicating a fairly balanced customer base.
#
# 2. **Product categories:** Clothing and Electronics generate strong sales volumes, while Electronics shows a high revenue contribution. This indicates that both sales volume and product price influence overall revenue performance.
#
# 3. **Transaction value:** Younger age groups generally show higher average transaction values than older age groups. The analysis also shows that quantity purchased has a positive relationship with total transaction amount, although price per unit also has a major influence.
#
# 4. **Correlation analysis:** Price per Unit and Total Amount have a strong positive correlation, while Quantity also has a positive relationship with Total Amount. This suggests that product pricing and quantity are important drivers of transaction revenue.
#
# ## Actionable Business Recommendations
#
# ### 1. Target high-value customer groups
# The business should create personalised promotions and loyalty offers for age groups with higher average transaction values to encourage repeat purchases and increase customer lifetime value.
#
# ### 2. Promote high-performing product categories
# Electronics and Clothing should receive greater promotional attention because they contribute strongly to sales and revenue. Bundles and cross-selling offers can be used to increase the average transaction value.
#
# ### 3. Increase quantity per transaction
# The business can introduce quantity-based discounts, bundle deals, and "Buy More, Save More" offers to encourage customers to purchase additional items in each transaction.
#
# ### 4. Use customer demographics for targeted marketing
# Marketing campaigns should be tailored to different age groups and genders rather than using the same promotion for all customers. This can improve campaign relevance and conversion rates.
#
# ### 5. Focus on pricing and product mix
# Since Price per Unit has a strong relationship with Total Amount, the business should analyse product pricing and identify opportunities to promote higher-value products without negatively affecting customer demand.
